# %%
import pandas as pd

# %%
df = pd.read_csv('medical_dataset.csv')
df.head(10)
# Out:
#    patient_id  age sex   TSH  Free_T4  Free_T3  Cortisol  Adrenaline  \
# 0           1   64   F  2.54     15.4     4.89     344.0        40.6
# 1           2   31   M  1.16     19.4     7.93     378.0        73.7
# 2           3   26   M  2.42     13.0     5.21     297.0        50.8
# 3           4   35   F  3.00     12.6     3.95     234.0        96.5
# 4           5   30   F  0.25     52.9     8.21     976.0       160.8
# 5           6   85   F  3.56     14.5     5.32     602.0        54.9
# 6           7   31   M  2.25     15.6     5.57     715.0       185.2
# 7           8   47   F  1.66     15.1     4.89     565.0        12.3
# 8           9   20   M  2.37     17.6     7.17     683.0       215.9
# 9          10   62   F  3.00     15.0     5.21     476.0        25.0
#
#    Noradrenaline  Estrogen  ...    FSH  Prolactin  Insulin  Leptin  Glucagon  \
# 0          382.0      16.5  ...  115.3       11.6     76.5   22.57     170.0
# 1          488.0      11.9  ...    5.6        9.5     12.2    2.39      80.0
# 2          175.0      24.6  ...    8.5       10.4      8.0    2.52     105.0
# 3          224.0     124.4  ...    8.7        7.3     12.9    5.83      79.0
# 4          882.0     162.5  ...    6.3       23.0     39.8   27.25     147.0
# 5          382.0      14.2  ...  129.4        7.9     30.8   29.45     124.0
# 6         1138.0      31.3  ...   11.8       14.3     24.9   18.08      71.0
# 7          527.0      48.1  ...    4.2       21.3     16.8    5.05     160.0
# 8          874.0      19.9  ...    6.2       11.0     17.6    4.34      88.0
# 9          511.0      11.4  ...   89.9       19.7     11.9    9.36     132.0
#
#    Hemoglobin   RBC   WBC  Platelets   ESR
# 0       141.0  4.09   7.9      298.0  10.0
# 1       159.0  5.10   7.4      286.0   7.0
# 2       151.0  5.00   7.4      298.0   2.0
# 3       143.0  4.67  12.2      390.0  21.0
# 4       138.0  4.19   9.1      276.0  10.0
# 5       140.0  5.18   4.9      320.0  15.0
# 6       159.0  5.19   8.5      361.0   8.0
# 7       149.0  4.82   7.5      276.0  10.0
# 8       129.0  4.51  10.1      275.0   7.0
# 9       150.0  4.46   7.2      264.0  16.0
#
# [10 rows x 23 columns]

# %%
df.describe()
# Out:
#         patient_id          age          TSH     Free_T4     Free_T3  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.00000
# mean    500.500000    45.266000     3.146500    16.66650     5.05323
# std     288.819436    17.842859     5.314297     6.51126     1.56404
# min       1.000000    18.000000     0.010000     4.10000     1.53000
# 25%     250.750000    30.000000     1.567500    13.60000     4.16750
# 50%     500.500000    44.000000     2.310000    16.00000     4.96500
# 75%     750.250000    58.000000     2.960000    18.50000     5.74250
# max    1000.000000    89.000000    52.890000    59.50000    14.54000
#
#           Cortisol   Adrenaline  Noradrenaline     Estrogen  Progesterone  \
# count  1000.000000  1000.000000    1000.000000  1000.000000   1000.000000
# mean    455.105000    72.500600     530.069000    92.779900      5.309620
# std     170.106673    53.063529     284.564614   258.978992     22.932144
# min     101.000000     3.000000      21.000000     2.300000      0.060000
# 25%     334.750000    38.475000     328.750000    21.400000      0.520000
# 50%     415.000000    51.750000     467.000000    31.100000      0.760000
# 75%     546.000000    80.350000     689.000000    73.575000      1.180000
# max    1030.000000   262.500000    1424.000000  2969.600000    264.360000
#
#        ...          FSH    Prolactin      Insulin       Leptin     Glucagon  \
# count  ...  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean   ...    22.475000    15.308200    21.921700    11.540620   107.745000
# std    ...    32.257162    17.832412    12.989989     8.846393    36.678185
# min    ...     0.400000     1.400000     0.800000     0.670000    16.000000
# 25%    ...     5.400000     9.700000    13.700000     5.420000    85.000000
# 50%    ...     8.100000    12.600000    19.000000     8.550000   102.000000
# 75%    ...    13.625000    16.400000    27.100000    15.170000   123.000000
# max    ...   129.500000   203.300000    79.300000    54.600000   249.000000
#
#         Hemoglobin          RBC          WBC    Platelets          ESR
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    137.813000     4.433330     8.064100   275.532000    10.847000
# std      16.746895     0.530896     3.531378    72.413927     9.178553
# min      80.000000     2.880000     2.900000    70.000000     0.000000
# 25%     131.000000     4.180000     5.975000   227.000000     6.000000
# 50%     139.000000     4.495000     7.100000   273.000000     8.000000
# 75%     149.000000     4.792500     9.100000   320.000000    12.000000
# max     177.000000     5.650000    24.800000   564.000000    60.000000
#
# [8 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
output_dir = 'plots'
os.makedirs(output_dir, exist_ok=True)
for column in df.columns:
    plt.figure(figsize=(8, 6))
    if df[column].dtype == 'object' or len(df[column].unique()) < 10:
        sns.countplot(data=df, x=column)
    else:
        sns.histplot(data=df, x=column, kde=True)

    plt.title(f'Distribution of {column}')
    plt.savefig(os.path.join(output_dir, f'{column}_distribution.png'))
    plt.close()
# Out:
# Summary Statistics:
# ==================================================
#
# Розподіл за віковими групами:
# age_group
# 18-29    258
# 30-49    373
# 50-69    279
# 70+       90
# Name: count, dtype: int64
#
# Розподіл за статтю:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 25
#      23 print(df['age_group'].value_counts().sort_index())
#      24 print("\nРозподіл за статтю:")
# ---> 25 print(df['gender'].value_counts())
#      26 print("\nРозподіл за рівнем фізичної активності:")
#      27 df['activity_level'] = pd.cut(df['physical_activity_minutes_per_week'],
#      28                               bins=[-1, 0, 150, 300, np.inf], labels=['None', 'Low', 'Moderate', 'High'])
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'gender'
